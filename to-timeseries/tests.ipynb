# %%
from imapclient import IMAPClient
import pandas as pd
import os

# %%
EEG = {}
FFT_WaveBands_Motion = {}
with IMAPClient('outlook.office365.com', port=993) as server:
    print(os.environ.get('EMAIL_USERNAME'), os.environ.get('EMAIL_PASSWORD'))
    server.login(os.environ.get('EMAIL_USERNAME'), os.environ.get('EMAIL_PASSWORD'))
    server.select_folder('INBOX')
    
    messages = server.search(['SUBJECT', 'EEG'])
    for uid, message_data in server.fetch(messages, 'RFC822').items():
        EEG[uid] = str(message_data)

    messages = server.search(['SUBJECT', 'FFT_WaveBands_Motion'])
    for uid, message_data in server.fetch(messages, 'RFC822').items():
        FFT_WaveBands_Motion[uid] = str(message_data)
# Out:
# None None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-423c91d2d287> in <module>
#       3 with IMAPClient('outlook.office365.com', port=993) as server:
#       4     print(os.environ.get('EMAIL_USERNAME'), os.environ.get('EMAIL_PASSWORD'))
# ----> 5     server.login(os.environ.get('EMAIL_USERNAME'), os.environ.get('EMAIL_PASSWORD'))
#       6     server.select_folder('INBOX')
#       7
#
# ~/anaconda3/lib/python3.8/site-packages/imapclient/imapclient.py in login(self, username, password)
#     373         """
#     374         try:
# --> 375             rv = self._command_and_check(
#     376                 "login",
#     377                 to_unicode(username),
#
# ~/anaconda3/lib/python3.8/site-packages/imapclient/imapclient.py in _command_and_check(self, command, *args, **kwargs)
#    1705         else:
#    1706             meth = getattr(self._imap, to_unicode(command))
# -> 1707             typ, data = meth(*args)
#    1708         self._checkok(command, typ, data)
#    1709         if unpack:
#
# ~/anaconda3/lib/python3.8/imaplib.py in login(self, user, password)
#     599         NB: 'password' will be quoted.
#     600         """
# --> 601         typ, dat = self._simple_command('LOGIN', user, self._quote(password))
#     602         if typ != 'OK':
#     603             raise self.error(dat[-1])
#
# ~/anaconda3/lib/python3.8/imaplib.py in _quote(self, arg)
#    1195     def _quote(self, arg):
#    1196
# -> 1197         arg = arg.replace('\\', '\\\\')
#    1198         arg = arg.replace('"', '\\"')
#    1199
#
# AttributeError: 'NoneType' object has no attribute 'replace'

# %%
cleaned = {}
for key, val in EEG.items():
    cleaned[key] = [int(x) for x in EEG[key].split('EEG,\\r\\n')[-1].split(',\\r\\n') if not '\\' in x]

cleaned = {}
for key, val in FFT_WaveBands_Motion.items():
    cleaned[key] = pd.DataFrame([x.split(',') for x in FFT_WaveBands_Motion[25320].split('Magnitude,\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n\\r\\n')[-1].replace('=\\r\\n','').split('\\r\\n') if ',' in x and ':' in x and not 'a' in x and not 'b' in x], dtype=float)

cleaned
# Out:
# {25323: [1937,
#   1842,
#   1332,
#   -600,
#   -2048,
#   -2048,
#   -1932,
#   76,
#   1841,
#   2005,
#   1923,
#   1834,
#   1478,
#   -155,
#   -2048,
#   -2048,
#   -2048,
#   -500,
#   1560,
#   1996,
#   1925,
#   1841,
#   1609,
#   355,
#   -1676,
#   -2048,
#   -2048,
#   -1094,
#   1097,
#   1980,
#   1939,
#   1856,
#   1696,
#   744,
#   -1318,
#   -2048,
#   -2048,
#   -1435,
#   722,
#   1946,
#   1943,
#   ...],
#  25320:               0         1         2         3          4          5   \
#  0    18:48:59.52  82.78233  98.09113  92.67601  81.324320  48.580470
#  1    18:48:59.52  82.78233  98.09113  92.67601  81.324320  48.580470
#  2    18:48:59.52  82.78233  98.09113  92.67601  81.324320  48.580470
#  3    18:48:59.52  82.78233  98.09113  92.67601  81.324320  48.580470
#  4    18:48:59.52  82.78233  98.09113  92.67601  81.324320  48.580470
#  ..           ...       ...       ...       ...        ...        ...
#  187  18:49:06.51  19.06964  14.85571  15.27154  11.172120  10.975310
#  188  18:49:06.64  21.36860  15.36224  15.05173  11.153180   8.633893
#  189  18:49:06.64  21.36860  15.36224  15.05173  11.153180   8.633893
#  190  18:49:06.77  24.44760  12.02705  14.01077   8.469663   8.567141
#  191  18:49:06.77  24.44760  12.02705  14.01077   8.469663   8.567141
#
#              6          7         8         9   ...        40        41  \
#  0    45.807280  36.840120  24.96087  25.85902  ...  681.3514  557.6247
#  1    45.807280  36.840120  24.96087  25.85902  ...  681.3514  557.6247
#  2    45.807280  36.840120  24.96087  25.85902  ...  681.3514  557.6247
#  3    45.807280  36.840120  24.96087  25.85902  ...  681.3514  557.6247
#  4    45.807280  36.840120  24.96087  25.85902  ...  681.3514  557.6247
#  ..         ...        ...       ...       ...  ...       ...       ...
#  187  12.004370   8.899601  12.74655  14.35051  ...  681.3514  557.6247
#  188  10.217100  10.983030  12.50477  14.37074  ...  681.3514  557.6247
#  189  10.217100  10.983030  12.50477  14.37074  ...  681.3514  557.6247
#  190   9.313428   8.621471   9.37692  11.22606  ...  681.3514  557.6247
#  191   9.313428   8.621471   9.37692  11.22606  ...       NaN       NaN
#
#             42        43        44        45        46        47        48  \
#  0    289.0511  534.4832  668.1426  0.050555  0.026565 -0.065629  0.086998
#  1    289.0511  534.4832  668.1426  0.050555  0.026565 -0.065629  0.086998
#  2    289.0511  534.4832  668.1426  0.050555  0.026565 -0.065629  0.086998
#  3    289.0511  534.4832  668.1426  0.050555  0.026565 -0.065629  0.086998
#  4    289.0511  534.4832  668.1426  0.050555  0.026565 -0.065629  0.086998
#  ..        ...       ...       ...       ...       ...       ...       ...
#  187  289.0511  534.4832  668.1426  0.215156 -0.345541 -0.233570  0.469304
#  188  289.0511  534.4832  668.1426  0.163956 -0.388208 -0.186637  0.460891
#  189  289.0511  534.4832  668.1426  0.163956 -0.388208 -0.186637  0.460891
#  190  289.0511  534.4832  668.1426  0.155423 -0.379675 -0.212237  0.461902
#  191       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#         49
#  0
#  1
#  2
#  3
#  4
#  ..    ...
#  187
#  188
#  189
#  190
#  191  None
#
#  [192 rows x 50 columns]}

# %%
import argparse
import smtplib
from imapclient import IMAPClient
# import mailparser

# %%
# !pip install mailparser
# Out:
# ERROR: Could not find a version that satisfies the requirement mailparser (from versions: none)
# ERROR: No matching distribution found for mailparser

# %%
# !pip3 install --upgrade pip3
# Out:
# ERROR: Could not find a version that satisfies the requirement pip3 (from versions: none)
# ERROR: No matching distribution found for pip3
